# %%
a=5

# %%
import numpy as np

# %%
a = [10,20,30,40]

# %%
type(a)
# Out:
# list

# %%
x = np.array(a)

# %%
print(x)
# Out:
# [10 20 30 40]

# %%
type(x)
# Out:
# numpy.ndarray

# %%
a = [1,2,3,4]
b = [10,20,30,40]
x = np.array([a,b])

# %%
print(x)
# Out:
# [[ 1  2  3  4]
#  [10 20 30 40]]
